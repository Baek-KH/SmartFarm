# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pyperclip
import time
import csv
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

# %%
import pandas as pd
data_ix = pd.date_range("2020/04/13",periods=365,freq="D") #일
print(data_ix)
# Out:
# DatetimeIndex(['2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16',
#                '2020-04-17', '2020-04-18', '2020-04-19', '2020-04-20',
#                '2020-04-21', '2020-04-22',
#                ...
#                '2021-04-03', '2021-04-04', '2021-04-05', '2021-04-06',
#                '2021-04-07', '2021-04-08', '2021-04-09', '2021-04-10',
#                '2021-04-11', '2021-04-12'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
>>>DatetimeIndex(['2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16',
               '2020-04-17'],
              dtype='datetime64[ns]', freq='D')

# %%
import numpy as np 
import random

data_ix = pd.date_range("2020/01/01",periods=365,freq="D") #월

a = np.random.rand(365)
b =[a,a+1]


df_ts = pd.DataFrame( a*100 , columns=['출하량'] , index = data_ix)
df_ts.to_excel('dumy.xlsx')
print(df_ts)
# Out:
#                   출하량
# 2020-01-01  19.499756
# 2020-01-02  83.196744
# 2020-01-03  50.038102
# 2020-01-04  96.317495
# 2020-01-05  34.628016
# ...               ...
# 2020-12-26  10.690365
# 2020-12-27  54.268279
# 2020-12-28  30.546022
# 2020-12-29  38.935794
# 2020-12-30  71.675452
#
# [365 rows x 1 columns]

# %%
data1 = pd.date_range("2020/01/01",periods=12,freq="m") #월
print(data1) 
df_ts_missing = pd.DataFrame([800,1000,800,1500,1000,3000,2800,3500,4000,2000,1200,1500]

                             , columns=['col']

                             , index=data1)
df_fixed_freq = df_ts_missing.resample('D').first()

print(df_fixed_freq)
# df_fixed_freq = df_fixed_freq.fillna(method='ffill')
df_fixed_freq=df_fixed_freq.interpolate( method = 'linear')
print(df_fixed_freq)
df_fixed_freq.to_excel('dumyData.xlsx')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='M')
#                col
# 2020-01-31   800.0
# 2020-02-01     NaN
# 2020-02-02     NaN
# 2020-02-03     NaN
# 2020-02-04     NaN
# ...            ...
# 2020-12-27     NaN
# 2020-12-28     NaN
# 2020-12-29     NaN
# 2020-12-30     NaN
# 2020-12-31  1500.0
#
# [336 rows x 1 columns]
#                     col
# 2020-01-31   800.000000
# 2020-02-01   806.896552
# 2020-02-02   813.793103
# 2020-02-03   820.689655
# 2020-02-04   827.586207
# ...                 ...
# 2020-12-27  1461.290323
# 2020-12-28  1470.967742
# 2020-12-29  1480.645161
# 2020-12-30  1490.322581
# 2020-12-31  1500.000000
#
# [336 rows x 1 columns]

# %%
data2 = pd.date_range("2020/01/01",periods=12,freq="m") #월
print(data2) 
df_ts_missing = pd.DataFrame([900,1200,500,1300,1800,2800,3500,3500,2000,1900,1600,1100]

                             , columns=['col']

                             , index=data2)
df_fixed_freq = df_ts_missing.resample('D').first()

print(df_fixed_freq)
# df_fixed_freq = df_fixed_freq.fillna(method='ffill')
df_fixed_freq=df_fixed_freq.interpolate( method = 'linear')
print(df_fixed_freq)
df_fixed_freq.to_excel('dumyData1.xlsx')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='M')
#                col
# 2020-01-31   900.0
# 2020-02-01     NaN
# 2020-02-02     NaN
# 2020-02-03     NaN
# 2020-02-04     NaN
# ...            ...
# 2020-12-27     NaN
# 2020-12-28     NaN
# 2020-12-29     NaN
# 2020-12-30     NaN
# 2020-12-31  1100.0
#
# [336 rows x 1 columns]
#                     col
# 2020-01-31   900.000000
# 2020-02-01   910.344828
# 2020-02-02   920.689655
# 2020-02-03   931.034483
# 2020-02-04   941.379310
# ...                 ...
# 2020-12-27  1164.516129
# 2020-12-28  1148.387097
# 2020-12-29  1132.258065
# 2020-12-30  1116.129032
# 2020-12-31  1100.000000
#
# [336 rows x 1 columns]

# %%
test1.col.plot()
test.col.plot()
# Out:
# <AxesSubplot:>

# %%
test = pd.read_excel('dumyData.xlsx')
test1 = pd.read_excel('dumyData1.xlsx')

# %%
from scipy import stats
import matplotlib.pyplot as plt

x= test.col
y = test1.col

result = stats.linregress(test.col,test1.col)
print(result)

slope, intercept, r_value, p_value, stderr = result
plt.scatter(x,y)
X = np.array(x)

plt.plot(X, slope*X + intercept, c = 'red')
plt.xlabel('출하량 1')
plt.ylabel('출하량 2')
plt.title('년도별 변화에 따른 출하량')
plt.show()
# Out:
# LinregressResult(slope=0.7321123560441589, intercept=457.83623627248835, rvalue=0.8314376163279223, pvalue=2.983000866681436e-87, stderr=0.026770176284262048, intercept_stderr=59.98317643587394)
# C:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44160 (\N{HANGUL SYLLABLE GEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49353 (\N{HANGUL SYLLABLE SAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 회귀선 : y = slope * X + intercept
# 기계학습모델 즉, 소비량(예측) = 기울기 * 예측생산량 + intercept
y_value = []
result_dict = dict()

for i in range(0,4000):
    result_dict[i]= slope * i + intercept
    
print(result_dict)
# Out:
# {0: 457.83623627248835, 1: 458.56834862853253, 2: 459.30046098457666, 3: 460.03257334062084, 4: 460.76468569666497, 5: 461.49679805270915, 6: 462.2289104087533, 7: 462.96102276479746, 8: 463.69313512084165, 9: 464.4252474768858, 10: 465.15735983292996, 11: 465.8894721889741, 12: 466.62158454501827, 13: 467.3536969010624, 14: 468.0858092571066, 15: 468.81792161315076, 16: 469.5500339691949, 17: 470.28214632523907, 18: 471.0142586812832, 19: 471.7463710373274, 20: 472.4784833933715, 21: 473.2105957494157, 22: 473.9427081054599, 23: 474.674820461504, 24: 475.4069328175482, 25: 476.1390451735923, 26: 476.8711575296365, 27: 477.6032698856806, 28: 478.3353822417248, 29: 479.067494597769, 30: 479.7996069538131, 31: 480.5317193098573, 32: 481.2638316659014, 33: 481.9959440219456, 34: 482.72805637798973, 35: 483.4601687340339, 36: 484.19228109007804, 37: 484.9243934461222, 38: 485.6565058021664, 39: 486.38861815821053, 40: 487.1207305142547, 41: 487.85284287029884, 42: 488.584955226343, 43: 4
# ...

# %%
전년도 = 1000
result_dict[1000]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13676\1837253916.py in <module>
#       3
#       4
# ----> 5 df = pd.DataFrame.from_dict(result_dict)
#       6 df
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1591             raise ValueError("only recognize index or columns for orient")
#    1592
# -> 1593         return cls(data, index=index, columns=columns, dtype=dtype)
#    1594
#    1595     def to_numpy(
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...

# %%
print(test)
# Out:
#     Unnamed: 0          col
# 0   2020-01-31   800.000000
# 1   2020-02-01   806.896552
# 2   2020-02-02   813.793103
# 3   2020-02-03   820.689655
# 4   2020-02-04   827.586207
# ..         ...          ...
# 331 2020-12-27  1461.290323
# 332 2020-12-28  1470.967742
# 333 2020-12-29  1480.645161
# 334 2020-12-30  1490.322581
# 335 2020-12-31  1500.000000
#
# [336 rows x 2 columns]

# %%
import MySQLdb, random, datetime, re

conn = MySQLdb.connect(host='localhost', port=3306, db='spring', user='root', password='12345')
cursor = conn.cursor()

# %%
# !pip install pymysql
# !pip install sqlalchemy
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
import pymysql
db_connection_str = 'mysql+pymysql://root:12345@localhost/spring'
db_connection = create_engine(db_connection_str)
conn = db_connection.connect()
test.to_sql(name='python', con=db_connection, if_exists='append',index=False)
